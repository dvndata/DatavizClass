# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data_csv = "data/mouse_drug_data.csv"
clinical_trial_data_csv = "data/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
mouse_drug_data = pd.read_csv(mouse_drug_data_csv)
clinical_trial_data = pd.read_csv(clinical_trial_data_csv)
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
# Combine the data into a single dataset
combined_data = pd.merge(clinical_trial_data, mouse_drug_data, how="left", on="Mouse ID")

# Display the data table for preview
combined_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites       Drug
# 0     b128          0                45.0                 0  Capomulin
# 1     f932          0                45.0                 0   Ketapril
# 2     g107          0                45.0                 0   Ketapril
# 3     a457          0                45.0                 0   Ketapril
# 4     c819          0                45.0                 0   Ketapril

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
mean_TV = combined_data.groupby(['Drug', 'Timepoint']).mean()['Tumor Volume (mm3)']

# Convert to DataFrame
mean_TV_df = pd.DataFrame({"Mean":mean_TV})

# Preview DataFrame
mean_TV_df
# Out:
#                           Mean
# Drug      Timepoint
# Capomulin 0          45.000000
#           5          44.266086
#           10         43.084291
#           15         42.064317
#           20         40.716325
# ...                        ...
# Zoniferol 25         55.432935
#           30         57.713531
#           35         60.089372
#           40         62.916692
#           45         65.960888
#
# [100 rows x 1 columns]

# %%
Capomulin_results = mean_TV_df[(mean_TV_df["Drug"] == "Capomulin")]
Ceftamin_results = merge_std_mean[(merge_std_mean["Drug"] == "Ceftamin")]
Infubinol_results = merge_std_mean[(merge_std_mean["Drug"] == "Infubinol")]
Ketapril_results = merge_std_mean[(merge_std_mean["Drug"] == "Ketapril")]
Naftisol_results = merge_std_mean[(merge_std_mean["Drug"] == "Naftisol")]
Placebo_results = merge_std_mean[(merge_std_mean["Drug"] == "Placebo")]
Propriva_results = merge_std_mean[(merge_std_mean["Drug"] == "Propriva")]
Ramicane_results = merge_std_mean[(merge_std_mean["Drug"] == "Ramicane")]
Stelasyn_results = merge_std_mean[(merge_std_mean["Drug"] == "Stelasyn")]
Zoniferol_results = merge_std_mean[(merge_std_mean["Drug"] == "Zoniferol")]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Drug'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-d2eb14320d17> in <module>
# ----> 1 Capomulin_results = mean_TV_df[(mean_TV_df["Drug"] == "Capomulin")]
#       2 Ceftamin_results = merge_std_mean[(merge_std_mean["Drug"] == "Ceftamin")]
#       3 Infubinol_results = merge_std_mean[(merge_std_mean["Drug"] == "Infubinol")]
#       4 Ketapril_results = merge_std_mean[(merge_std_mean["Drug"] == "Ketapril")]
#       5 Naftisol_results = merge_std_mean[(merge_std_mean["Drug"] == "Naftisol")]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Drug'

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
StdErr_TV = combined_data.groupby(['Drug', 'Timepoint']).std()['Tumor Volume (mm3)']

# Convert to DataFrame
StdErr_TV_df = pd.DataFrame({"StdErr":StdErr_TV})

# Preview DataFrame
StdErr_TV_df
# Out:
#                        StdErr
# Drug      Timepoint
# Capomulin 0          0.000000
#           5          2.242964
#           10         3.513422
#           15         4.108369
#           20         4.362915
# ...                       ...
# Zoniferol 25         2.410052
#           30         3.098552
#           35         3.297993
#           40         3.736102
#           45         3.755037
#
# [100 rows x 1 columns]

# %%
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)
# 0  Capomulin          0            0.000000
# 1  Capomulin          5            0.448593
# 2  Capomulin         10            0.702684
# 3  Capomulin         15            0.838617
# 4  Capomulin         20            0.909731

# %%
# Minor Data Munging to Re-Format the Data Frames
merge_std_mean = pd.merge(mean_TV_df, StdErr_TV_df, how="left", on=["Timepoint", "Drug"], right_index=False)

# Preview that Reformatting worked
merge_std_mean
# Out:
#                           Mean    StdErr
# Timepoint Drug
# 0         Capomulin  45.000000  0.000000
# 5         Capomulin  44.266086  2.242964
# 10        Capomulin  43.084291  3.513422
# 15        Capomulin  42.064317  4.108369
# 20        Capomulin  40.716325  4.362915
# ...                        ...       ...
# 25        Zoniferol  55.432935  2.410052
# 30        Zoniferol  57.713531  3.098552
# 35        Zoniferol  60.089372  3.297993
# 40        Zoniferol  62.916692  3.736102
# 45        Zoniferol  65.960888  3.755037
#
# [100 rows x 2 columns]

# %%
# Create data series by Drug names using conditionals
#Capomulin_results = df_merge_std_mean[(df_merge_std_mean["Drug"] == "Capomulin")]
Ceftamin_results = merge_std_mean[(merge_std_mean["Drug"] == "Ceftamin")]
Infubinol_results = merge_std_mean[(merge_std_mean["Drug"] == "Infubinol")]
Ketapril_results = merge_std_mean[(merge_std_mean["Drug"] == "Ketapril")]
Naftisol_results = merge_std_mean[(merge_std_mean["Drug"] == "Naftisol")]
Placebo_results = merge_std_mean[(merge_std_mean["Drug"] == "Placebo")]
Propriva_results = merge_std_mean[(merge_std_mean["Drug"] == "Propriva")]
Ramicane_results = merge_std_mean[(merge_std_mean["Drug"] == "Ramicane")]
Stelasyn_results = merge_std_mean[(merge_std_mean["Drug"] == "Stelasyn")]
Zoniferol_results = merge_std_mean[(merge_std_mean["Drug"] == "Zoniferol")]

# Group each by school name
#ninth_graders_scores = ninth_graders.groupby(["school_name"]).mean()["math_score"]
#tenth_graders_scores = tenth_graders.groupby(["school_name"]).mean()["math_score"]
#eleventh_graders_scores = eleventh_graders.groupby(["school_name"]).mean()["math_score"]
#twelfth_graders_scores = twelfth_graders.groupby(["school_name"]).mean()["math_score"]

# Combine series into single data frame
results_by_drug = pd.DataFrame({"Capomulin": Capomulin_results, "Ceftamin": Ceftamin_results})

# Minor data munging
#scores_by_grade = scores_by_grade[["9th", "10th", "11th", "12th"]]
#scores_by_grade.index.name = None

# Display the data frame
results_by_drug
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Drug'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-a83998b77410> in <module>
#       1 # Create data series by Drug names using conditionals
#       2 #Capomulin_results = df_merge_std_mean[(df_merge_std_mean["Drug"] == "Capomulin")]
# ----> 3 Ceftamin_results = merge_std_mean[(merge_std_mean["Drug"] == "Ceftamin")]
#       4 Infubinol_results = merge_std_mean[(merge_std_mean["Drug"] == "Infubinol")]
#       5 Ketapril_results = merge_std_mean[(merge_std_mean["Drug"] == "Ketapril")]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Drug'

# %%
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334

# %%
# Generate the Plot (with Error Bars)

# Save the Figure

# %%
# Show the Figure
plt.show()

# %% [markdown]
# ![Tumor Response to Treatment](../Images/treatment.png)

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 

# Convert to DataFrame

# Preview DataFrame

# %%
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.160000
#           10                 0.320000
#           15                 0.375000
#           20                 0.652174

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 

# Convert to DataFrame

# Preview DataFrame

# %%
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.074833
#           10                 0.125433
#           15                 0.132048
#           20                 0.161621

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview that Reformatting worked

# %%
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334

# %%
# Generate the Plot (with Error Bars)

# Save the Figure

# Show the Figure

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/spread.png)

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)

# Convert to DataFrame

# Preview DataFrame

# %%
# Out:
#         Drug  Timepoint  Mouse Count
# 0  Capomulin          0           25
# 1  Capomulin          5           25
# 2  Capomulin         10           25
# 3  Capomulin         15           24
# 4  Capomulin         20           23

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview the Data Frame

# %%
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# 10               23        24        23         22
# 15               17        24        23         21
# 20               17        23        21         17

# %%
# Generate the Plot (Accounting for percentages)

# Save the Figure

# Show the Figure
plt.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/survival.png)

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug

# Display the data to confirm

# %%
# Out:
# Drug
# Capomulin   -19.475303
# Ceftamin     42.516492
# Infubinol    46.123472
# Ketapril     57.028795
# Naftisol     53.923347
# Placebo      51.297960
# Propriva     47.241175
# Ramicane    -22.320900
# Stelasyn     52.085134
# Zoniferol    46.579751
# dtype: float64

# %%
# Store all Relevant Percent Changes into a Tuple


# Splice the data between passing and failing drugs


# Orient widths. Add labels, tick marks, etc. 


# Use functions to label the percentages of changes


# Call functions to implement the function calls


# Save the Figure


# Show the Figure
fig.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/change.png)
